# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import random
import re
import unicodedata
import datetime
import itertools
# %matplotlib inline

# %%
box_scores = pd.read_excel('data/box_scores/box_score_2017.xlsx')

# %%
box_scores.head(n=5)
# Out:
#    ast  blk  drb  fg  fg3  fg3_pct  fg3a  fg_pct  fga  ft   ...    stl_pct  \
# 0    0    2    3   5    3     0.60     5   0.385   13   3   ...        1.5
# 1    3    0    4   8    1     0.25     4   0.444   18   2   ...        1.6
# 2    1    1    1   7    1     0.50     2   0.412   17   2   ...        0.0
# 3    0    1    2   0    0     0.00     2   0.000    5   0   ...        0.0
# 4    3    0    5   0    0      NaN     0   0.000    1   0   ...        2.5
#
#    tov_pct trb_pct ts_pct usg_pct  g_num          g_id team       date  season
# 0     11.3    11.0  0.512    22.7      1  201610250CLE  NYK 2016-10-25    2017
# 1     17.5     8.6  0.503    32.1      1  201610250CLE  NYK 2016-10-25    2017
# 2     18.3     5.2  0.475    31.2      1  201610250CLE  NYK 2016-10-25    2017
# 3     28.6     7.9  0.000    15.1      1  201610250CLE  NYK 2016-10-25    2017
# 4     50.0    15.9  0.000     4.3      1  201610250CLE  NYK 2016-10-25    2017
#
# [5 rows x 42 columns]

# %%
box_scores.columns
# Out:
# Index([u'ast', u'blk', u'drb', u'fg', u'fg3', u'fg3_pct', u'fg3a', u'fg_pct',
#        u'fga', u'ft', u'ft_pct', u'fta', u'id', u'link', u'mp', u'orb', u'pf',
#        u'player', u'pts', u'sec', u'stl', u'tov', u'trb', u'ast_pct',
#        u'blk_pct', u'def_rtg', u'drb_pct', u'efg_pct', u'fg3a_per_fga_pct',
#        u'fta_per_fga_pct', u'off_rtg', u'orb_pct', u'stl_pct', u'tov_pct',
#        u'trb_pct', u'ts_pct', u'usg_pct', u'g_num', u'g_id', u'team', u'date',
#        u'season'],
#       dtype='object')

# %%
print len(np.unique(box_scores['id']))
print len(np.unique(box_scores['player']))
# Out:
# 486
# 486

# %%
p_id = box_scores['id'].iloc[0]
player_df = box_scores[box_scores['id'] == p_id]
season
# Out:
#     ast  blk  drb  fg  fg3  fg3_pct  fg3a  fg_pct  fga  ft   ...    stl_pct  \
# 0     0    2    3   5    3    0.600     5   0.385   13   3   ...        1.5
# 0     2    1    5   7    1    0.250     4   0.636   11   6   ...        0.0
# 3     1    1    4   7    2    0.286     7   0.389   18   2   ...        0.0
# 3     0    2    6   0    0      NaN     0   0.000    4   3   ...        1.7
# 4     1    0    3  10    4    0.571     7   0.667   15   3   ...        0.0
# 3     1    2    7  10    3    0.429     7   0.556   18   5   ...        0.0
# 2     1    2    7   7    4    0.500     8   0.467   15   3   ...        3.1
# 1     1    2    4   5    0    0.000     2   0.333   15   4   ...        2.0
# 4     2    0    3   9    2    0.250     8   0.563   16   1   ...        0.0
# 0     1    1    9   8    2    0.400     5   0.500   16   6   ...        0.0
# 0     3    1    3  13    3    0.429     7   0.591   22   6   ...        1.3
# ...

# %%
for p_id in np.unique(box_scores['id']):
    player_df = box_scores[box_scores['id'] == p_id]
